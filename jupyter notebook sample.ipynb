# %% [markdown]
# # Basic Flowchart
#
# ```mermaid
# flowchart TD
#     A[Step 1: Start] --> B[Step 2: Process Input]
#     B --> C[Step 3: Execute Logic]
#     C --> D[Step 4: Generate Output]
#     D --> E[Step 5: End]
# ```
